# %% [markdown]
# # Lecture 19 Notebook

# %%
import pandas as pd
import numpy as np
from numpy import nan

# %%
nan == True

# %%
nan == False

# %%
nan == 0

# %%
nan == ''

# %%
nan == None

# %%
pd.isnull(nan)

# %%
pd.notnull(nan)

# %%
pets2 = pd.read_csv('morepets.csv')
pets2

# %%
petsorig = pets2
petsorig

# %%
pets2.fillna(0)
pets2

# %%
pets2.fillna(0, inplace = True)
pets2

# %%
newpets = pets2.fillna(0)
newpets

# %%
pets2.dtypes

# %%
pets2['petname_str'] = pets2['petname'].astype(str)
pets2.dtypes

# %%
petsorig.fillna(method = 'bfill')
petsorig

# %%
pets3 = pd.read_csv('morepets.csv')
pets3.interpolate()

# %%
pets4 = pd.read_csv('morepets.csv')
pets4

# %%
pets_dropna = pets4.dropna()
pets_dropna

# %%
dfd = pd.read_csv('petdata.csv')
dfd

# %%
nodup = dfd.drop_duplicates()
nodup

# %%
nodup.reset_index(inplace=True) 
nodup

# %%
new = nodup.rename(columns={"index": "patient_id"})
new

# %%
#nodup.pivot(columns = 'petname')
nodup.T

# %%
# reading csv file from url
data = pd.read_csv("nba.csv")

# dropping null value columns to avoid errors
data.dropna(inplace=True)
data

# %%
#Split at most once at a space, expand into separate columns in the new df
new = data["Name"].str.split(" ", n=1, expand = True)
new

# %%
# making separate first and last name columns from new data frame
data["First Name"] = new[0]
data["Last Name"] = new[1]
 
# Dropping old Name columns
data.drop(columns=["Name"], inplace=True)
data

# %%
# split height column by hyphen
new2 = data["Height"].str.split("-", n=1, expand = True)
new2

# %%
# making separate ft and in columns from new data frame
data["Height_ft"] = new[0]
data["Height_in"] = new[1]
 
# Dropping old Name columns
data.drop(columns=["Height"], inplace=True)
data

# %%
date = "10/30/2024"
date2 = pd.to_datetime(date)
date2

# %%
date2.date

# %%
date

# %%
str(date2)[:10]
