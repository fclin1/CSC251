# %%
#Lecture 13 Notebook
import numpy as np

# %%
# create a NumPy array from a list
arr1 = np.array([3, 2.6, 8, 9.2])
arr1
# Out:
# array([3. , 2.6, 8. , 9.2])

# %%
# what happens with non-homogeneous items?
arr1b = np.array(["stuff", 3.12, 200])
arr1b
# Out:
# array(['stuff', '3.12', '200'], dtype='<U32')

# %%
# using equal-length lists
arr2 = np.array([[1, 3, 5], [2, 4, 6]])
arr2
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
# using nonequal-length lists
arr2 = np.array([[1, 3, 5], [2, 4, 6, 8]])
arr2

# %%
# using a tuple
arr3 = np.array((10, 20, 30))
arr3

# %%
# randomly generate an arary of values
arr4 = np.random.randn(3, 2)
arr4

# %%
# create an array of zeros
arr5 = np.zeros(8)
arr5

# %%
# create an array of zeros
arr6 = np.ones(4)
arr6

# %%
# initialize with another array
arr7 = np.ones_like(arr4)
arr7

# %%
# use the arange function
arr8a = np.arange(12)
arr8a

# %%
arr8 = np.arange(2, 26, 3)
print(arr8)

# %%
# specify the element datatype
arr9 = np.array([5.4, 10.9, 15.2], dtype = np.float64)
print(arr9.shape, arr9.dtype)

# %%
# cast an array to create another
arr10 = arr9.astype(np.int32)
print(arr10, arr10.dtype)

# %%
arr11 = arr4 + arr7
arr11

# %%
arr12 = np.arange(10)
arr13 = np.ones(10) * 10
print(arr12)
print(arr13)

# %%
print(arr13 % arr12)

# %%
print(arr4 > arr7)
