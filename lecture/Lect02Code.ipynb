# %%
a = 2
print(a)
# Out:
# 2

# %%
b = 2.0
print(b)
# Out:
# 2.0

# %%
print(int(b))
# Out:
# 2

# %%
print(b)
# Out:
# 2.0

# %%
b
# Out:
# 2.0

# %%
c = "3.14"
c
# Out:
# '3.14'

# %%
print(float(c))
# Out:
# 3.14

# %%
print(int(c))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(int(c))
#
# ValueError: invalid literal for int() with base 10: '3.14'

# %%
e = float(c)
f = int(e)
f

# %%
d = "hello"
print(float(d))

# %%
a = 3
print(type(a))
print(id(a))

# %%
import sys
sys.getsizeof(3.0)

# %%
sys.getsizeof(3)

# %%
1/4

# %%
10/5

# %%
1//4

# %%
-1//4

# %%
2**1**3

# %%
a = 3
print(a)
a = "hello"
print(a)
a = 3.999999
print(a)

# %%
bignum = 3_000_000
bignum

# %%
print("1", a,
      b)

# %%
print(" this is the first line \
this is the second line.")

# %%
# How do you... Question 4
x = 1
y = 2
z = 3
print(f"{x}{y}{z}")
print(x, y, z, sep="")
# Out:
# 123
# 123
